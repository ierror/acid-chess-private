# %%
import os

from pathlib import Path
from glob import glob

from cv2 import cv2

import numpy as np
import IPython

# %%
def imshow(img):
    _,ret = cv2.imencode('.jpg', img) 
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %%
for image_path in glob("*.jpeg"):
    print(image_path)
    image = cv2.imread(image_path)
    imshow(image)

    black_or_white = input("Color[b]: ") or "b"
    occupied_or_not = input("Occupied[n]: ") or "n"

    if black_or_white == "b":
        black_or_white = "black"
    elif black_or_white == "w":
        black_or_white = "white"
    else:
        raise RuntimeError()

    if occupied_or_not == "y":
        occupied_or_not = "occupied"
    elif occupied_or_not == "n":
        occupied_or_not = "empty"
    else:
        raise RuntimeError()

    target_dir = f"data/squares/{black_or_white}_{occupied_or_not}"
    Path(target_dir).mkdir(parents=True, exist_ok=True)
    image_counter = len(glob(f"{target_dir}/*-0.jpeg"))
        
    target_path = f"{target_dir}/{image_counter:05d}-{angle}.jpeg"
    cv2.imwrite(target_path, image)
        
    os.unlink(image_path)
# Out:
# 330.jpeg
# Color[b]:  w
# Occupied[n]:
# 12.jpeg
# Color[b]:  w
# Occupied[n]:
# 263.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 326.jpeg
# Color[b]:
# Occupied[n]:  y
# 45.jpeg
# Color[b]:
# Occupied[n]:
# 234.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 371.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 306.jpeg
# Color[b]:
# Occupied[n]:
# 243.jpeg
# Color[b]:  w
# Occupied[n]:
# 32.jpeg
# Color[b]:
# Occupied[n]:
# 185.jpeg
# Color[b]:
# Occupied[n]:  y
# 351.jpeg
# Color[b]:
# Occupied[n]:  y
# 214.jpeg
# Color[b]:
# Occupied[n]:  y
# 347.jpeg
# Color[b]:
# Occupied[n]:  y
# 202.jpeg
# Color[b]:  w
# Occupied[n]:
# 310.jpeg
# Color[b]:
# Occupied[n]:  y
# 255.jpeg
# Color[b]:
# Occupied[n]:  y
# 24.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 193.jpeg
# Color[b]:  w
# Occupied[n]:
# 107.jpeg
# Color[b]:
# Occupied[n]:
# 279.jpeg
# Color[b]:
# Occupied[n]:  y
# 296.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 150.jpeg
# Color[b]:
# Occupied[n]:  y
# 280.jpeg
# Color[b]:  w
# Occupied[n]:  y
# 146.jpeg
# ...
